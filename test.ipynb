# %%
from dotenv import load_dotenv
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

load_dotenv(verbose=True)

print(os.getenv("SPOTIPY_CLIENT_ID2"))
# Out:
# 485408ce2c7942169293ea09d4ca507d

# %%
birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Portraits (+ Remixes)
# Portraits
# Young Heart
# Beautiful Lies
# Fire Within
# Live in London
# Birdy (Deluxe Version)
# Birdy

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="YOUR_APP_CLIENT_ID",
                                                           client_secret="YOUR_APP_CLIENT_SECRET"))

results = sp.search(q='weezer', limit=10)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])
# Out:
# 0 Buddy Holly
# 1 Island In The Sun
# 2 Say It Ain't So
# 3 Undone - The Sweater Song
# 4 Beverly Hills
# 5 I Just Threw Out The Love Of My Dreams
# 6 Africa
# 7 Hash Pipe
# 8 My Name Is Jonas
# 9 Think Fast (feat. Weezer)

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=os.getenv("SPOTIPY_CLIENT_ID"),
                                               client_secret=os.getenv("SPOTIPY_CLIENT_SECRET"),
                                               redirect_uri="http://localhost:8888/callback",
                                               scope="user-library-read"))

results = sp.current_user_saved_tracks()
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# 0 Calpurnia  –  Blame
# 1 Calpurnia  –  Greyhound
# 2 Calpurnia  –  Say It Ain't So - Recorded At Spotify Studios NYC
# 3 Kirk Matthews  –  Let Me Sign
# 4 Good Neighbours  –  Home
# 5 Vishal Chandrashekhar  –  Uraiyum Theeyil
# 6 PRI  –  Kanna Varuvaayo?
# 7 Vaishalini  –  Was It All You Deserved?
# 8 Beyoncé  –  TEXAS HOLD 'EM
# 9 Manu Chao  –  Me Gustas Tu
# 10 Djo  –  End of Beginning
# 11 Tame Impala  –  Feels Like We Only Go Backwards
# 12 Ms. Lauryn Hill  –  Doo Wop (That Thing)
# 13 Bring Me The Horizon  –  DArkSide
# 14 Emei  –  Irresponsible
# 15 Emei  –  Distracted
# 16 Emei  –  Love Me Not
# 17 EthanUno  –  tu
# 18 Emei  –  That Girl
# 19 Emei  –  Better People To Leave On Read

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth (client_id = os.getenv('SPOTIFY_CLIENT_ID'),
                                                client_secret = os.getenv('SPOTIFY_CLIENT_SECRET'),
                                                redirect_uri="http://localhost:8888/callback",
                                                scope="user-library-read user-top-read"))

# sp.current_user_top_tracks(limit=20, offset=0, time_range='medium_term')
sp.current_user_top_artists(limit=20, offset=0, time_range='medium_term')
# Out:
# {'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2dIgFjalVxs4ThymZ67YCE'},
#    'followers': {'href': None, 'total': 14745925},
#    'genres': ['k-pop', 'k-pop boy group', 'pop'],
#    'href': 'https://api.spotify.com/v1/artists/2dIgFjalVxs4ThymZ67YCE',
#    'id': '2dIgFjalVxs4ThymZ67YCE',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb0610877c41cb9cc12ad39cc0',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051740610877c41cb9cc12ad39cc0',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1780610877c41cb9cc12ad39cc0',
#      'width': 160}],
#    'name': 'Stray Kids',
#    'popularity': 82,
#    'type': 'artist',
#    'uri': 'spotify:artist:2dIgFjalVxs4ThymZ67YCE'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/68KmkJeZGfwe1OUaivBa2L'},
#    'followers': {'href': None, 'total': 3743358},
# ...

# %%
sp. user_playlists("sionabeaudoin03", limit=50, offset=0)
# Out:
# {'href': 'https://api.spotify.com/v1/users/sionabeaudoin03/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5K1XdJInV38d26GnvZRAqy'},
#    'href': 'https://api.spotify.com/v1/playlists/5K1XdJInV38d26GnvZRAqy',
#    'id': '5K1XdJInV38d26GnvZRAqy',
#    'images': [{'height': None,
#      'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb83f36182c7296908349cc2ed',
#      'width': None}],
#    'name': 'Desi Songs I Recommend',
#    'owner': {'display_name': 'PRI',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/22gxcujbf7t72cwzad6ebbsgy'},
#     'href': 'https://api.spotify.com/v1/users/22gxcujbf7t72cwzad6ebbsgy',
#     'id': '22gxcujbf7t72cwzad6ebbsgy',
#     'type': 'user',
#     'uri': 'spotify:user:22gxcujbf7t72cwzad6ebbsgy'},
#    'primary_color': None,
#    'public': True,
# ...

# %%
#could use the polularity of artists, what countries they're available in, compare songs in short_term vs medium_term vs long_term
top_tracks_JSON = sp.current_user_top_tracks(limit=50, offset=0, time_range='long_term')
df = pd.DataFrame(top_tracks_JSON)

csv_file = '../output.csv'
df.to_csv(csv_file, index=False)

# %%
# sp2 = spotipy.Spotify(auth_manager=SpotifyOAuth (client_id = os.getenv('SPOTIFY_CLIENT_ID2'),
#                                                 client_secret = os.getenv('SPOTIFY_CLIENT_SECRET2'),
#                                                 redirect_uri="http://localhost:8888/callback",
#                                                 scope="user-library-read user-top-read"))

# #could use the polularity of artists, what countries they're available in, compare songs in short_term vs medium_term vs long_term
# top_tracks_JSON = sp2.current_user_top_tracks(limit=50, offset=0, time_range='long_term')
# df = pd.DataFrame(top_tracks_JSON)

# csv_file = '../output2.csv'
# df.to_csv(csv_file, index=False)

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=os.getenv("SPOTIPY_CLIENT_ID2"),
                                               client_secret=os.getenv("SPOTIPY_CLIENT_SECRET2"),
                                               redirect_uri="http://localhost:8888/callback",
                                               scope="user-library-read"))

results = sp.current_user_saved_tracks()
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# 0 Calpurnia  –  Blame
# 1 Calpurnia  –  Greyhound
# 2 Calpurnia  –  Say It Ain't So - Recorded At Spotify Studios NYC
# 3 Kirk Matthews  –  Let Me Sign
# 4 Good Neighbours  –  Home
# 5 Vishal Chandrashekhar  –  Uraiyum Theeyil
# 6 PRI  –  Kanna Varuvaayo?
# 7 Vaishalini  –  Was It All You Deserved?
# 8 Beyoncé  –  TEXAS HOLD 'EM
# 9 Manu Chao  –  Me Gustas Tu
# 10 Djo  –  End of Beginning
# 11 Tame Impala  –  Feels Like We Only Go Backwards
# 12 Ms. Lauryn Hill  –  Doo Wop (That Thing)
# 13 Bring Me The Horizon  –  DArkSide
# 14 Emei  –  Irresponsible
# 15 Emei  –  Distracted
# 16 Emei  –  Love Me Not
# 17 EthanUno  –  tu
# 18 Emei  –  That Girl
# 19 Emei  –  Better People To Leave On Read
